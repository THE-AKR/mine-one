# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # things to remember : axis=0 means row , axis=1 means col

# %%
df= pd.Series([1,2,3,4,5,6,np.nan,8]) #np.nan used for providing null values

# %%
df #by default it is in float
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    NaN
# 7    8.0
# dtype: float64

# %%
df= pd.DataFrame(np.random.randn(4,6),columns=list("Abcdef")) #random randn for float values

# %%
df
# Out:
#           A         b         c         d         e         f
# 0  0.774230 -0.524857  0.268011  0.465872 -0.109775 -0.007394
# 1 -0.367352 -1.409638  1.374124  0.906562 -0.786478  0.012707
# 2 -1.740181 -1.092108  0.216120 -0.321319 -0.020393 -0.098159
# 3  1.595575  0.686930  0.151064 -1.194477  1.493757  1.038973

# %%
# Dataframes

# %%
di1= {"name":["abc","cde","def","ghi","rts","hjo","lol","ffe","gfh"],"age":[11,12,13,14,15,16,np.nan,18,19],"marks":[100,110,120,130,np.nan,170,180,190,200]}

# %%
df1= pd.DataFrame(di1)
df1
# Out:
#   name   age  marks
# 0  abc  11.0  100.0
# 1  cde  12.0  110.0
# 2  def  13.0  120.0
# 3  ghi  14.0  130.0
# 4  rts  15.0    NaN
# 5  hjo  16.0  170.0
# 6  lol   NaN  180.0
# 7  ffe  18.0  190.0
# 8  gfh  19.0  200.0

# %%
df1.T #transpose of df , like col. will be row , row will be col.(not permanent)
# Out:
#            0      1      2      3     4      5      6      7      8
# name     abc    cde    def    ghi   rts    hjo    lol    ffe    gfh
# age     11.0   12.0   13.0   14.0  15.0   16.0    NaN   18.0   19.0
# marks  100.0  110.0  120.0  130.0   NaN  170.0  180.0  190.0  200.0

# %%
df1["name"] # if single list, it will display normal
# Out:
# 0    abc
# 1    cde
# 2    def
# 3    ghi
# 4    rts
# 5    hjo
# 6    lol
# 7    ffe
# 8    gfh
# Name: name, dtype: object

# %%
df1[["name"]] #in tabular form if use double list
# Out:
#   name
# 0  abc
# 1  cde
# 2  def
# 3  ghi
# 4  rts
# 5  hjo
# 6  lol
# 7  ffe
# 8  gfh

# %%
df1.columns #all columns name
# Out:
# Index(['name', 'age', 'marks'], dtype='object')

# %%
df1.dtypes #gives column datatypes info
# Out:
# name      object
# age      float64
# marks    float64
# dtype: object

# %%
df1.describe() #mean , count , quartiles, std, min , max
# Out:
#              age      marks
# count   8.000000    8.00000
# mean   14.750000  150.00000
# std     2.815772   39.27922
# min    11.000000  100.00000
# 25%    12.750000  117.50000
# 50%    14.500000  150.00000
# 75%    16.500000  182.50000
# max    19.000000  200.00000

# %%
df1.info() #info about df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    9 non-null      object
#  1   age     8 non-null      float64
#  2   marks   8 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 344.0+ bytes

# %%
url=input()
df=pd.read_csv(url)
df.head()
# Out:
# https://bit.ly/3R0Fay0
#                                  Title                     Genres  \
# 0                           Gut (2012)    Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                     Horror
# 2                  Sleepwalking (2017)                     Horror
# 3  Treasure Chest of Horrors II (2013)   Comedy| Horror| Thriller
# 4                       Infidus (2015)       Crime| Drama| Horror
#
#   Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# 0    26-Oct-12             USA          NaN            3.9         91 min
# 1    13-Jan-17             USA          NaN            NaN            NaN
# 2    21-Oct-17          Canada          NaN            NaN            NaN
# 3    23-Apr-13             USA    NOT RATED            3.7         82 min
# 4    10-Apr-15             USA          NaN            5.8         80 min
#
#                                                 Plot  \
# ...

# %%
df.loc[::-1,:].reset_index(drop=True)
# Out:
#                                      Title  \
# 0                        13 Cameras (2015)
# 1       BloodRayne: The Third Reich (2011)
# 2                       Talon Falls (2017)
# 3     The Exorcism of Molly Hartley (2015)
# 4               Victor Frankenstein (2015)
# ...                                    ...
# 3323                        Infidus (2015)
# 3324   Treasure Chest of Horrors II (2013)
# 3325                   Sleepwalking (2017)
# 3326       The Haunting of Mia Moss (2017)
# 3327                            Gut (2012)
#
#                                    Genres Release Date Release Country  \
# 0                           Drama| Horror    15-Apr-16             USA
# 1      Action| Adventure| Fantasy| Horror    17-Mar-12           Japan
# 2                                  Horror    13-Oct-17             USA
# 3                                  Horror     9-Oct-15             USA
# 4         Drama| Horror| Sci-Fi| Thriller    25-Nov-15             USA
# ...

# %%
df.index #to check no. of indexes (rows) (index= stop-1)
# Out:
# RangeIndex(start=0, stop=3328, step=1)

# %%
df.columns #show all columns name
# Out:
# Index(['Title', 'Genres', 'Release Date', 'Release Country', 'Movie Rating',
#        'Review Rating', 'Movie Run Time', 'Plot', 'Cast', 'Language',
#        'Filming Locations', 'Budget'],
#       dtype='object')

# %% [markdown]
# ## data WRangling

# %%
df["Title"] #single column
# Out:
# 0                                 Gut (2012)
# 1            The Haunting of Mia Moss (2017)
# 2                        Sleepwalking (2017)
# 3        Treasure Chest of Horrors II (2013)
# 4                             Infidus (2015)
#                         ...
# 3323              Victor Frankenstein (2015)
# 3324    The Exorcism of Molly Hartley (2015)
# 3325                      Talon Falls (2017)
# 3326      BloodRayne: The Third Reich (2011)
# 3327                       13 Cameras (2015)
# Name: Title, Length: 3328, dtype: object

# %%
#selecting multiple column

df[["Title","Budget"]]
# Out:
#                                      Title        Budget
# 0                               Gut (2012)           NaN
# 1          The Haunting of Mia Moss (2017)      $30,000
# 2                      Sleepwalking (2017)           NaN
# 3      Treasure Chest of Horrors II (2013)           NaN
# 4                           Infidus (2015)           NaN
# ...                                    ...           ...
# 3323            Victor Frankenstein (2015)  $40,000,000
# 3324  The Exorcism of Molly Hartley (2015)           NaN
# 3325                    Talon Falls (2017)           NaN
# 3326    BloodRayne: The Third Reich (2011)  $10,000,000
# 3327                     13 Cameras (2015)           NaN
#
# [3328 rows x 2 columns]

# %%
# selecting row

df[300:308]
# Out:
#                                           Title  \
# 300                         Speed Demons (2012)
# 301                     Anonymous Zombie (2017)
# 302                     The Rakugo Movie (2012)
# 303                             Daylight (2013)
# 304              Collective: Unconscious (2016)
# 305             But Deliver Us from Evil (2017)
# 306                    The Demonic Tapes (2017)
# 307  A Capital dos Mortos 2: Mundo Morto (2015)
#
#                                 Genres Release Date Release Country  \
# 300                             Horror         2012             USA
# 301                             Horror     1-Oct-17          Canada
# 302       Comedy| Crime| Drama| Horror     6-Apr-13           Japan
# 303          Horror| Mystery| Thriller    24-Aug-13              UK
# 304   Drama| Horror| Mystery| Thriller    13-Mar-16             USA
# 305                   Horror| Thriller    27-Apr-17             USA
# ...

# %% [markdown]
# ## LOC

# %% [markdown]
# ### extracting particular row , particular value

# %%
#display first row  of only specific column

df.loc[0,"Genres"]
# Out:
# ' Drama| Horror| Thriller'

# %%
df.loc[0:1,["Title","Language","Budget"]] # first two multiple columns and rows values
# Out:
#                              Title Language    Budget
# 0                       Gut (2012)  English       NaN
# 1  The Haunting of Mia Moss (2017)  English  $30,000

# %%
#multiple rows and multiple values

df.loc[0:4,["Title","Review Rating","Genres"]].sort_index(ascending=False)
# Out:
#                                  Title  Review Rating  \
# 4                       Infidus (2015)            5.8
# 3  Treasure Chest of Horrors II (2013)            3.7
# 2                  Sleepwalking (2017)            NaN
# 1      The Haunting of Mia Moss (2017)            NaN
# 0                           Gut (2012)            3.9
#
#                       Genres
# 4       Crime| Drama| Horror
# 3   Comedy| Horror| Thriller
# 2                     Horror
# 1                     Horror
# 0    Drama| Horror| Thriller

# %%
## apply conditions

# %%
df[df["Review Rating"]>6.0]
# Out:
#                             Title  \
# 7         Parasyte: Part 2 (2015)
# 17                 Falling (2016)
# 23                Darkroom (2017)
# 34      Yaamirukka Bayamey (2014)
# 35        Grindsploitation (2016)
# ...                           ...
# 3314    The Carmilla Movie (2017)
# 3316            Odd Thomas (2013)
# 3319  Insidious: Chapter 3 (2015)
# 3321         Before I Wake (2016)
# 3322               13 Sins (2014)
#
#                                                  Genres Release Date  \
# 7                         Action| Drama| Horror| Sci-Fi    25-Apr-15
# 17                     Drama| Horror| Romance| Thriller     8-Apr-16
# 23                                        Drama| Horror    18-Jan-17
# 34                                       Comedy| Horror     9-May-14
# 35              Action| Crime| Horror| Sci-Fi| Thriller    31-Oct-16
# ...                                                 ...          ...
# ...

# %%
df.dtypes
# Out:
# Title                 object
# Genres                object
# Release Date          object
# Release Country       object
# Movie Rating          object
# Review Rating        float64
# Movie Run Time        object
# Plot                  object
# Cast                  object
# Language              object
# Filming Locations     object
# Budget                object
# dtype: object

# %%
## set index

# %%
df.set_index("Title") #title as a index(not permanently , inplace=true for permanent)
# Out:
#                                                                    Genres  \
# Title
# Gut (2012)                                        Drama| Horror| Thriller
# The Haunting of Mia Moss (2017)                                    Horror
# Sleepwalking (2017)                                                Horror
# Treasure Chest of Horrors II (2013)              Comedy| Horror| Thriller
# Infidus (2015)                                       Crime| Drama| Horror
# ...                                                                   ...
# Victor Frankenstein (2015)                Drama| Horror| Sci-Fi| Thriller
# The Exorcism of Molly Hartley (2015)                               Horror
# Talon Falls (2017)                                                 Horror
# BloodRayne: The Third Reich (2011)     Action| Adventure| Fantasy| Horror
# 13 Cameras (2015)                                           Drama| Horror
#
#                                      Release Date Release Country  \
# ...

# %%
df.set_index("Title",inplace=True)

# %%
df
# Out:
#                                                                    Genres  \
# Title
# Gut (2012)                                        Drama| Horror| Thriller
# The Haunting of Mia Moss (2017)                                    Horror
# Sleepwalking (2017)                                                Horror
# Treasure Chest of Horrors II (2013)              Comedy| Horror| Thriller
# Infidus (2015)                                       Crime| Drama| Horror
# ...                                                                   ...
# Victor Frankenstein (2015)                Drama| Horror| Sci-Fi| Thriller
# The Exorcism of Molly Hartley (2015)                               Horror
# Talon Falls (2017)                                                 Horror
# BloodRayne: The Third Reich (2011)     Action| Adventure| Fantasy| Horror
# 13 Cameras (2015)                                           Drama| Horror
#
#                                      Release Date Release Country  \
# ...

# %%
df.loc["13 Cameras (2015)"] #now we extract the details with movies name
# Out:
# Genres                                                   Drama| Horror
# Release Date                                                 15-Apr-16
# Release Country                                                    USA
# Movie Rating                                                       NaN
# Review Rating                                                      5.1
# Movie Run Time                                                  87 min
# Plot                 Directed by Victor Zarcoff. With Neville Archa...
# Cast                 Neville Archambault|Sean Carrigan|PJ McCabe|Br...
# Language                                                       English
# Filming Locations                           Escondido, California, USA
# Budget                                                             NaN
# Name: 13 Cameras (2015), dtype: object

# %%
#reset the index
df.reset_index(inplace=True)

# %%
df
# Out:
#                                      Title  \
# 0                               Gut (2012)
# 1          The Haunting of Mia Moss (2017)
# 2                      Sleepwalking (2017)
# 3      Treasure Chest of Horrors II (2013)
# 4                           Infidus (2015)
# ...                                    ...
# 3323            Victor Frankenstein (2015)
# 3324  The Exorcism of Molly Hartley (2015)
# 3325                    Talon Falls (2017)
# 3326    BloodRayne: The Third Reich (2011)
# 3327                     13 Cameras (2015)
#
#                                    Genres Release Date Release Country  \
# 0                 Drama| Horror| Thriller    26-Oct-12             USA
# 1                                  Horror    13-Jan-17             USA
# 2                                  Horror    21-Oct-17          Canada
# 3                Comedy| Horror| Thriller    23-Apr-13             USA
# 4                    Crime| Drama| Horror    10-Apr-15             USA
# ...

# %%
## Sort index

# %%
df.sort_index(ascending=False) #descending order
# Out:
#                                      Title  \
# 3327                     13 Cameras (2015)
# 3326    BloodRayne: The Third Reich (2011)
# 3325                    Talon Falls (2017)
# 3324  The Exorcism of Molly Hartley (2015)
# 3323            Victor Frankenstein (2015)
# ...                                    ...
# 4                           Infidus (2015)
# 3      Treasure Chest of Horrors II (2013)
# 2                      Sleepwalking (2017)
# 1          The Haunting of Mia Moss (2017)
# 0                               Gut (2012)
#
#                                    Genres Release Date Release Country  \
# 3327                        Drama| Horror    15-Apr-16             USA
# 3326   Action| Adventure| Fantasy| Horror    17-Mar-12           Japan
# 3325                               Horror    13-Oct-17             USA
# 3324                               Horror     9-Oct-15             USA
# 3323      Drama| Horror| Sci-Fi| Thriller    25-Nov-15             USA
# ...

# %%
## AND operator

# %%
df[(df["Genres"]=="Horror") | (df["Review Rating"]==4.6)]#? why, if "and" replace by "or" it works but not in "and" even the values exist
# Out:
#                                      Title                      Genres  \
# 8             Stranger in the House (2015)   Horror| Mystery| Thriller
# 47             Bloody Chainsaw Girl (2016)              Action| Horror
# 87              House with 100 Eyes (2013)                      Horror
# 155              Everyone Must Die! (2012)                      Horror
# 157                       Ice Cream (2014)            Horror| Thriller
# ...                                    ...                         ...
# 3183         Boo! A Madea Halloween (2016)              Comedy| Horror
# 3302                 The Scarehouse (2014)     Crime| Horror| Thriller
# 3313                       Nurse 3D (2013)            Horror| Thriller
# 3324  The Exorcism of Molly Hartley (2015)                      Horror
# 3325                    Talon Falls (2017)                      Horror
#
#      Release Date Release Country Movie Rating  Review Rating Movie Run Time  \
# ...

# %%
df.Review.isin([4.6]).value_counts()
# Out:
# False    3246
# True       82
# Name: Review, dtype: int64

# %%
df.rename(columns= {"Review Rating": "Review"}, inplace=True)

# %% [markdown]
# ## Adding new column

# %%
# example 
c1= ["ind","pak","sl","bang","afg"]
df2["c1"]=c1 #this will add a new column with name "c1"

# %% [markdown]
# ## Rename the column name

# %%
### syntax : df.rename(columns={"old_name":"new_name"},inplace=true)

# %%
df.rename(columns= {"Movie Run Time": "Run Time"}, inplace=True)

# %%
df.head(n=10)
# Out:
#                                  Title                          Genres  \
# 0                           Gut (2012)         Drama| Horror| Thriller
# 1      The Haunting of Mia Moss (2017)                          Horror
# 2                  Sleepwalking (2017)                          Horror
# 3  Treasure Chest of Horrors II (2013)        Comedy| Horror| Thriller
# 4                       Infidus (2015)            Crime| Drama| Horror
# 5                   In Extremis (2017)                Horror| Thriller
# 6                    Ghostlight (2013)         Drama| Horror| Thriller
# 7              Parasyte: Part 2 (2015)   Action| Drama| Horror| Sci-Fi
# 8         Stranger in the House (2015)       Horror| Mystery| Thriller
# 9            Tutak Tutak Tutiya (2016)                  Comedy| Horror
#
#   Release Date Release Country Movie Rating  Review Run Time  \
# 0    26-Oct-12             USA          NaN     3.9   91 min
# 1    13-Jan-17             USA          NaN     NaN      NaN
# ...

# %% [markdown]
# ## Changing row values

# %%
df.loc[4]= ["bhaago bhoot aaya","Most horror","30-feb-100B.C.","Earth616","PG-13",10.0,"1000min","Directed by Casper the Friendly ghost","Annabelle|THE nun|","Ancient","Ghar me","100 Billion"]

# %%
df.loc[4] #changed successfully
# Out:
# Title                                    bhaago bhoot aaya
# Genres                                         Most horror
# Release Date                                30-feb-100B.C.
# Release Country                                   Earth616
# Movie Rating                                         PG-13
# Review                                                10.0
# Run Time                                           1000min
# Plot                 Directed by Casper the Friendly ghost
# Cast                                    Annabelle|THE nun|
# Language                                           Ancient
# Filming Locations                                  Ghar me
# Budget                                         100 Billion
# Name: 4, dtype: object

# %% [markdown]
# ## Changing rows single values

# %%
df.loc[2,"Movie Rating"]="Unrated"

# %%
df # changed successfully
# Out:
#                                      Title  \
# 0                               Gut (2012)
# 1          The Haunting of Mia Moss (2017)
# 2                      Sleepwalking (2017)
# 3      Treasure Chest of Horrors II (2013)
# 4                        bhaago bhoot aaya
# ...                                    ...
# 3323            Victor Frankenstein (2015)
# 3324  The Exorcism of Molly Hartley (2015)
# 3325                    Talon Falls (2017)
# 3326    BloodRayne: The Third Reich (2011)
# 3327                     13 Cameras (2015)
#
#                                    Genres    Release Date Release Country  \
# 0                 Drama| Horror| Thriller       26-Oct-12             USA
# 1                                  Horror       13-Jan-17             USA
# 2                                  Horror       21-Oct-17          Canada
# 3                Comedy| Horror| Thriller       23-Apr-13             USA
# ...

# %%
## replace the value (like we wants to replace all NAn values with PG-13 in "movie rating col.")

# %%
df["Movie Rating"].replace({"None":"PG-13"},inplace=True) #? why its not working
df
# Out:
#                                      Title  \
# 0                               Gut (2012)
# 1          The Haunting of Mia Moss (2017)
# 2                      Sleepwalking (2017)
# 3      Treasure Chest of Horrors II (2013)
# 4                        bhaago bhoot aaya
# ...                                    ...
# 3323            Victor Frankenstein (2015)
# 3324  The Exorcism of Molly Hartley (2015)
# 3325                    Talon Falls (2017)
# 3326    BloodRayne: The Third Reich (2011)
# 3327                     13 Cameras (2015)
#
#                                    Genres    Release Date Release Country  \
# 0                 Drama| Horror| Thriller       26-Oct-12             USA
# 1                                  Horror       13-Jan-17             USA
# 2                                  Horror       21-Oct-17          Canada
# 3                Comedy| Horror| Thriller       23-Apr-13             USA
# ...

# %%
## remove the columns

# %%
df.drop(columns=["Movie Rating"],inplace=True)

# %%
df
# Out:
#                                      Title  \
# 0                               Gut (2012)
# 1          The Haunting of Mia Moss (2017)
# 2                      Sleepwalking (2017)
# 3      Treasure Chest of Horrors II (2013)
# 4                        bhaago bhoot aaya
# ...                                    ...
# 3323            Victor Frankenstein (2015)
# 3324  The Exorcism of Molly Hartley (2015)
# 3325                    Talon Falls (2017)
# 3326    BloodRayne: The Third Reich (2011)
# 3327                     13 Cameras (2015)
#
#                                    Genres    Release Date Release Country  \
# 0                 Drama| Horror| Thriller       26-Oct-12             USA
# 1                                  Horror       13-Jan-17             USA
# 2                                  Horror       21-Oct-17          Canada
# 3                Comedy| Horror| Thriller       23-Apr-13             USA
# ...

# %%
## delete the row

# %%
df.drop(index=0)
# Out:
#                                      Title  \
# 1          The Haunting of Mia Moss (2017)
# 2                      Sleepwalking (2017)
# 3      Treasure Chest of Horrors II (2013)
# 4                        bhaago bhoot aaya
# 5                       In Extremis (2017)
# ...                                    ...
# 3323            Victor Frankenstein (2015)
# 3324  The Exorcism of Molly Hartley (2015)
# 3325                    Talon Falls (2017)
# 3326    BloodRayne: The Third Reich (2011)
# 3327                     13 Cameras (2015)
#
#                                    Genres    Release Date Release Country  \
# 1                                  Horror       13-Jan-17             USA
# 2                                  Horror       21-Oct-17          Canada
# 3                Comedy| Horror| Thriller       23-Apr-13             USA
# 4                             Most horror  30-feb-100B.C.        Earth616
# ...

# %%
(df["Review"]==4.8).value_counts()
# Out:
# False    3245
# True       83
# Name: Review, dtype: int64

# %%
(df["Review"].isna()).value_counts() #null values
# Out:
# False    3076
# True      252
# Name: Review, dtype: int64

# %% [markdown]
# ## sort_value

# %%
# display the column according to review ratings in ascending order

df.sort_values(by="Review")
# Out:
#                                            Title  \
# 1499                          Countrycide (2017)
# 1691                  Una Comedia Macabra (2017)
# 1454                         A Rain Woman (2016)
# 2833                         Potato Salad (2015)
# 79    Dead Walkers: Rise of the 4th Reich (2013)
# ...                                          ...
# 2857                             Wildling (2017)
# 2891                    Alpha Delta Zatan (2017)
# 2894                                Totem (2017)
# 3113                         Patient Zero (2017)
# 3260                         Buckout Road (2017)
#
#                                 Genres Release Date Release Country  Review  \
# 1499                            Horror     8-Sep-17             USA     1.0
# 1691                    Comedy| Horror    21-Sep-17            Peru     1.0
# 1454                            Horror     4-Jun-16           Japan     1.2
# ...

# %%
# display the column according to review ratings in descending order

df.sort_values(by="Review",ascending=False)
# Out:
#                                               Title  \
# 4                                 bhaago bhoot aaya
# 2569                           Bonehill Road (2017)
# 1961                          The Theta Girl (2017)
# 3314                      The Carmilla Movie (2017)
# 1855  Hotel Inferno 2: The Cathedral of Pain (2017)
# ...                                             ...
# 2857                                Wildling (2017)
# 2891                       Alpha Delta Zatan (2017)
# 2894                                   Totem (2017)
# 3113                            Patient Zero (2017)
# 3260                            Buckout Road (2017)
#
#                                 Genres    Release Date Release Country  \
# 4                          Most horror  30-feb-100B.C.        Earth616
# 2569                            Horror       27-Oct-17             USA
# 1961            Action| Horror| Sci-Fi       13-Oct-17             USA
# ...

# %%
#display one column in ascending and other one in descending

df.sort_values(by=["Review","Budget"],ascending=[True,False])
# Out:
#                                            Title  \
# 1691                  Una Comedia Macabra (2017)
# 1499                          Countrycide (2017)
# 1454                         A Rain Woman (2016)
# 2833                         Potato Salad (2015)
# 79    Dead Walkers: Rise of the 4th Reich (2013)
# ...                                          ...
# 2817                            Nosferatu (2017)
# 2857                             Wildling (2017)
# 2894                                Totem (2017)
# 3113                         Patient Zero (2017)
# 3260                         Buckout Road (2017)
#
#                                 Genres Release Date Release Country  Review  \
# 1691                    Comedy| Horror    21-Sep-17            Peru     1.0
# 1499                            Horror     8-Sep-17             USA     1.0
# 1454                            Horror     4-Jun-16           Japan     1.2
# ...

# %% [markdown]
# ## Aggregate Functions

# %%
#count the values in particular column

df["Genres"].value_counts()
# Out:
#  Horror                                                    1059
#  Horror| Thriller                                           474
#  Comedy| Horror                                             245
#  Horror| Mystery| Thriller                                  172
#  Drama| Horror| Thriller                                    161
#                                                            ...
#  Horror| Thriller| Western                                    1
#  Animation| Action| Adventure| Fantasy| Horror| Mystery       1
#  Action| Adventure| Horror| Mystery                           1
#  Fantasy| Horror| Mystery| Sci-Fi| Thriller                   1
#  Animation| Drama| Horror| Thriller                           1
# Name: Genres, Length: 262, dtype: int64

# %%
df["Language"].value_counts()
# Out:
# English                          2421
# Spanish                            96
# Japanese                           77
# Hindi                              37
# Filipino|Tagalog                   34
#                                  ...
# English|Japanese|Chinese            1
# English|Chinese                     1
# Danish|Danish                       1
# Tamil|Malayalam|Hindi|English       1
# Polish|English|Yiddish              1
# Name: Language, Length: 188, dtype: int64

# %%
df[df["Language"]=="Hindi" ]
# Out:
#                                                   Title  \
# 9                             Tutak Tutak Tutiya (2016)
# 37                                 Ek Thi Daayan (2013)
# 98                              Mumbai 125 KM 3D (2014)
# 111                           1920: Evil Returns (2012)
# 140                                        Ghost (2012)
# 220                                Chudail Story (2016)
# 314                  MSG the Warrior: Lion Heart (2016)
# 368                                  Khamoshiyan (2015)
# 370                           Rise of the Zombie (2013)
# 447                               Jattu Engineer (2017)
# 484                                     Sheitaan (2017)
# 576                    Saansein: The Last Breath (2016)
# 711                                   Neighbours (2014)
# 881            The Witch hour: Curse of the ring (2017)
# 991                               The Final Exit (2017)
# 1022                             Darr @ the Mall (2014)
# ...

# %%
## dataframe

# %%
a=pd.DataFrame() #empty df
a
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
## drop row values and columns

# %%
df1={"fist_col":[10,2,21,13,231],"second_col":["a","b","c","d","e"],"third_col":[0,1,0,1,1]}
df=pd.DataFrame(df1)
df
# Out:
#    fist_col second_col  third_col
# 0        10          a          0
# 1         2          b          1
# 2        21          c          0
# 3        13          d          1
# 4       231          e          1

# %%
df=df.assign(u=lambda x:x['fist_col']+x['third_col']) #assign a new column with lambda function

# %%
df.drop(2) #drop the 2nd row (axis=0 , by default)
# Out:
#    fist_col second_col  third_col    u
# 0        10          a          0   10
# 1         2          b          1    3
# 3        13          d          1   14
# 4       231          e          1  232

# %%
df.drop("u",axis=1) #single columns
# Out:
#    fist_col second_col  third_col
# 0        10          a          0
# 1         2          b          1
# 2        21          c          0
# 3        13          d          1
# 4       231          e          1

# %%
df.drop(["u","fist_col"],axis=1) #dropping multiple columns
# Out:
#   second_col  third_col
# 0          a          0
# 1          b          1
# 2          c          0
# 3          d          1
# 4          e          1

# %%
## Rename columns

# %%
df.rename(columns={"fist_col":"First_col","u":"fourth_col"})
# Out:
#    First_col second_col  third_col  fourth_col
# 0         10          a          0          10
# 1          2          b          1           3
# 2         21          c          0          21
# 3         13          d          1          14
# 4        231          e          1         232

# %%
#basic operations(aggregate function)

# %%
df.sum(axis=1) #adding like(in 0th index, 10+10, in 1st index 2+1+3)
# Out:
# 0     20
# 1      6
# 2     42
# 3     28
# 4    464
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# fist_col        277
# second_col    abcde
# third_col         3
# u               280
# dtype: object

# %%
df.mean(axis=0)
# Out:
# fist_col     55.4
# third_col     0.6
# u            56.0
# dtype: float64

# %%
df.std()
# Out:
# fist_col     98.398679
# third_col     0.547723
# u            98.602738
# dtype: float64

# %%
df.std(axis=1)
# Out:
# 0      5.773503
# 1      1.000000
# 2     12.124356
# 3      7.234178
# 4    133.080176
# dtype: float64

# %%
df.var()
# Out:
# fist_col     9682.3
# third_col       0.3
# u            9722.5
# dtype: float64

# %%
df.var(axis=1)
# Out:
# 0       33.333333
# 1        1.000000
# 2      147.000000
# 3       52.333333
# 4    17710.333333
# dtype: float64

# %%
df.describe()
# Out:
#          fist_col  third_col           u
# count    5.000000   5.000000    5.000000
# mean    55.400000   0.600000   56.000000
# std     98.398679   0.547723   98.602738
# min      2.000000   0.000000    3.000000
# 25%     10.000000   0.000000   10.000000
# 50%     13.000000   1.000000   14.000000
# 75%     21.000000   1.000000   21.000000
# max    231.000000   1.000000  232.000000

# %%
df.describe(percentiles=[.01,.02,.05,.09]).round(2)
# Out:
#        fist_col  third_col       u
# count      5.00       5.00    5.00
# mean      55.40       0.60   56.00
# std       98.40       0.55   98.60
# min        2.00       0.00    3.00
# 1%         2.32       0.00    3.28
# 2%         2.64       0.00    3.56
# 5%         3.60       0.00    4.40
# 9%         4.88       0.00    5.52
# 50%       13.00       1.00   14.00
# max      231.00       1.00  232.00

# %%
df.describe(percentiles=[.1,.2,.5,.9]).round(2) #? why (decimal)

# %%
#  To get summaries for categorical variables only (object column)
df.describe(include=['object'])
# Out:
#        second_col
# count           5
# unique          5
# top             a
# freq            1

# %%
df.describe(include='all')
# Out:
#           fist_col second_col  third_col           u
# count     5.000000          5   5.000000    5.000000
# unique         NaN          5        NaN         NaN
# top            NaN          a        NaN         NaN
# freq           NaN          1        NaN         NaN
# mean     55.400000        NaN   0.600000   56.000000
# std      98.398679        NaN   0.547723   98.602738
# min       2.000000        NaN   0.000000    3.000000
# 25%      10.000000        NaN   0.000000   10.000000
# 50%      13.000000        NaN   1.000000   14.000000
# 75%      21.000000        NaN   1.000000   21.000000
# max     231.000000        NaN   1.000000  232.000000

# %%
## Handle missing values

# %%
np.nan==np.nan
# Out:
# False

# %%
a=np.nan
b=np.nan
a==b
# Out:
# False

# %%
np.nan==np.nan
# Out:
# False

# %%
np.nan
# Out:
# nan
