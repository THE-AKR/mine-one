# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mpg= sns.load_dataset("mpg")

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg.shape
# Out:
# (398, 9)

# %%
mpg.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.describe(include='all')
# Out:
#                mpg   cylinders  displacement  horsepower       weight  \
# count   398.000000  398.000000    398.000000  392.000000   398.000000
# unique         NaN         NaN           NaN         NaN          NaN
# top            NaN         NaN           NaN         NaN          NaN
# freq           NaN         NaN           NaN         NaN          NaN
# mean     23.514573    5.454774    193.425879  104.469388  2970.424623
# std       7.815984    1.701004    104.269838   38.491160   846.841774
# min       9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000    262.000000  126.000000  3608.000000
# max      46.600000    8.000000    455.000000  230.000000  5140.000000
#
#         acceleration  model_year origin        name
# count     398.000000  398.000000    398         398
# ...

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
mpg.name.unique()
# Out:
# array(['chevrolet chevelle malibu', 'buick skylark 320',
#        'plymouth satellite', 'amc rebel sst', 'ford torino',
#        'ford galaxie 500', 'chevrolet impala', 'plymouth fury iii',
#        'pontiac catalina', 'amc ambassador dpl', 'dodge challenger se',
#        "plymouth 'cuda 340", 'chevrolet monte carlo',
#        'buick estate wagon (sw)', 'toyota corona mark ii',
#        'plymouth duster', 'amc hornet', 'ford maverick', 'datsun pl510',
#        'volkswagen 1131 deluxe sedan', 'peugeot 504', 'audi 100 ls',
#        'saab 99e', 'bmw 2002', 'amc gremlin', 'ford f250', 'chevy c20',
#        'dodge d200', 'hi 1200d', 'chevrolet vega 2300', 'toyota corona',
#        'ford pinto', 'plymouth satellite custom', 'ford torino 500',
#        'amc matador', 'pontiac catalina brougham', 'dodge monaco (sw)',
#        'ford country squire (sw)', 'pontiac safari (sw)',
#        'amc hornet sportabout (sw)', 'chevrolet vega (sw)',
# ...

# %%
mpg["mpg"].hist()
# Out:
# <AxesSubplot:>

# %%
mpg["cylinders"].hist()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(mpg)

# %%
mpg["cylinders"].unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
mpg["horsepower"].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
mpg["acceleration"].unique()
# Out:
# array([12. , 11.5, 11. , 10.5, 10. ,  nan,  8.5,  8. ,  9.5, 15. , 15.5,
#        16. , 14.5, 20.5, 17.5, 12.5, 14. , 13.5, 18.5, 13. , 19. , 19.5,
#        18. , 17. , 23.5, 16.5, 21. , 16.9, 14.9, 17.7, 15.3, 13.9, 12.8,
#        15.4, 17.6, 22.2, 22.1, 14.2, 17.4, 16.2, 17.8, 12.2, 16.4, 13.6,
#        15.7, 13.2, 21.9, 16.7, 12.1, 14.8, 18.6, 16.8, 13.7, 11.1, 11.4,
#        18.2, 15.8, 15.9, 14.1, 21.5, 14.4, 19.4, 19.2, 17.2, 18.7, 15.1,
#        13.4, 11.2, 14.7, 16.6, 17.3, 15.2, 14.3, 20.1, 24.8, 11.3, 12.9,
#        18.8, 18.1, 17.9, 21.7, 23.7, 19.9, 21.8, 13.8, 12.6, 16.1, 20.7,
#        18.3, 20.4, 19.6, 17.1, 15.6, 24.6, 11.6])

# %%
#x=mpg[["mpg","cylinders"]]
cor=mpg.corr()
sns.heatmap(cor)
cor
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
#corrleation

mpg- cylinders : negative correlation (70%)
mpg - cyclinders :

# %%
mpg.boxplot("mpg")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("cylinders")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("displacement")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("horsepower")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("weight")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("acceleration")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("model_year")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### outliers : mpg, horsepower , accleration

# %%
mpg[mpg["horsepower"].isna()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
#How to deal with null values 

1) if it is less , then we can remove the records
2) we can also replace them with mean/mode/medain.

# %%
#here , we have null values in horse power , 
#so I'm replacing the null values with mode (because it is a categorical column)

mpg[mpg.horsepower.isna()]=mpg.mode() 
#because it contains null values , thats why I'm getting 6 null values in all features

so, if you want to replace na with mode so directly input the mod value.

# %%
mpg.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin        name
# 0        73.0    usa  ford pinto
# 1         NaN    NaN         NaN

# %%
mpg['horsepower'].mode()
# Out:
# 0    150.0
# dtype: float64

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg['horsepower'].fillna(mpg['horsepower'].mode().iloc[0], inplace=True)

# %%
mpg['horsepower'].mode().iloc[0]
# Out:
# 150.0

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.dropna(axis='rows',inplace=True)

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.boxplot("horsepower")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # handling outliers

# %%
mpg.boxplot("mpg")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Using z-score

# %%
outliers=[]
def detect_outliers(a):
    threshold=3    #means 3rd standard deviation
    mean=np.mean(a)
    std=np.std(a)
    
    for i in a:
        z_score= (i-mean)/std
        if np.abs(z_score)>threshold:
            outliers.append(i)
    return outliers

# %%
outlier_mpg= detect_outliers(mpg['mpg'])
outlier_mpg
# Out:
# []

# %%
outlier_horse= detect_outliers(mpg["horsepower"])
outlier_horse
# Out:
# [220.0, 225.0, 225.0, 225.0, 230.0]

# %%
mpg[mpg["horsepower"].isin(outlier_horse)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 6    14.0          8         454.0       220.0    4354           9.0
# 8    14.0          8         455.0       225.0    4425          10.0
# 13   14.0          8         455.0       225.0    3086          10.0
# 95   12.0          8         455.0       225.0    4951          11.0
# 116  16.0          8         400.0       230.0    4278           9.5
#
#      model_year origin                      name
# 6            70    usa          chevrolet impala
# 8            70    usa          pontiac catalina
# 13           70    usa   buick estate wagon (sw)
# 95           73    usa  buick electra 225 custom
# 116          73    usa        pontiac grand prix

# %%
mpg[mpg["horsepower"].isin([220.0,225.0,225.0,230.0])]=150 #which is basically mode
#we can't assign the mode value after removing the columns due to mismatch in rows.(not confirm)
#because mode contain single value

# %%
mpg[mpg.horsepower.isin([220.0,225.0,225.0,230.0])]=150

# %%
mpg[mpg.horsepower.isin([220.0,225.0,225.0,230.0])]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
mpg.horsepower.value_counts()
# Out:
# 150.0    22
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 61.0      1
# 77.0      1
# 193.0     1
# 138.0     1
# 54.0      1
# Name: horsepower, Length: 93, dtype: int64

# %%
mpg[mpg.horsepower.isin([220.0,225.0,225.0,230.0])]=150

# %%
mpg['horsepower'].isin([220.0,225.0,225.0,230.0])=150
# Out:
#   File "<ipython-input-15-8425ca8d6eab>", line 1
#     mpg['horsepower'].isin([220.0,225.0,225.0,230.0])=150
#     ^
# SyntaxError: cannot assign to function call

# %%
mpg.boxplot('cylinders') #before passing value
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot('cylinders')
# Out:
# <AxesSubplot:>

# %%
mpg.horsepower.value_counts()
# Out:
# 150.0    27
# 90.0     20
# 88.0     19
# 110.0    18
# 100.0    17
#          ..
# 137.0     1
# 135.0     1
# 103.0     1
# 133.0     1
# 54.0      1
# Name: horsepower, Length: 90, dtype: int64

# %%
mpg.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
mpg.boxplot("cylinders")
# Out:
# <AxesSubplot:>

# %%
mpg.boxplot("horsepower")
# Out:
# <AxesSubplot:>

# %%
outlier_acc= detect_outliers(mpg["acceleration"])
outlier_acc
# Out:
# [150.0, 150.0, 150.0, 150.0, 150.0]

# %%
mpg.shape
# Out:
# (392, 9)

# %%
mpg.acceleration.value_counts().sum()
# Out:
# 392

# %%
mpg.acceleration.value_counts()
#92 unique entries out of 392 , it means it can treat as a categorical column
# Out:
# 14.5    23
# 15.5    21
# 16.0    16
# 14.0    16
# 13.5    15
#         ..
# 18.3     1
# 11.1     1
# 19.9     1
# 20.7     1
# 11.3     1
# Name: acceleration, Length: 95, dtype: int64

# %%
mpg.acceleration.mode()
# Out:
# 0    14.5
# dtype: float64

# %%
mpg[mpg["acceleration"].isin(outlier_acc)]
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 6    150.0        150         150.0       150.0     150         150.0
# 8    150.0        150         150.0       150.0     150         150.0
# 13   150.0        150         150.0       150.0     150         150.0
# 95   150.0        150         150.0       150.0     150         150.0
# 116  150.0        150         150.0       150.0     150         150.0
#
#      model_year origin name
# 6           150    150  150
# 8           150    150  150
# 13          150    150  150
# 95          150    150  150
# 116         150    150  150

# %%
mpg[mpg["acceleration"].isin([220,225,230,24.8,24.6])]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 299  27.2          4         141.0        71.0    3190          24.8
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin         name
# 299          79  europe  peugeot 504
# 394          82  europe    vw pickup

# %%
outlier_acc #???
# Out:
# [220.0, 225.0, 225.0, 225.0, 230.0, 24.8, 24.6]

# %%
mpg[mpg.acceleration==225.0]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
#remember mistakes start from outliers section.

# %%
mpg.boxplot("acceleration")
# Out:
# <AxesSubplot:>
