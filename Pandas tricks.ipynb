# %%
import numpy as np
import pandas as pd

# %%
url1="https://bit.ly/3qgC3H8"
movies=pd.read_csv(url1)

url2= "https://bit.ly/3x5pXVo"
stocks= pd.read_csv(url2)

url3="https://bit.ly/3D4GYTf"
ufo= pd.read_csv(url3)

url4="https://bit.ly/3D2HAsu"
drinks= pd.read_csv(url4)

url5="https://bit.ly/3Qnk24E"
titanic=pd.read_csv(url5)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1353             try:
# -> 1354                 h.request(req.get_method(), req.selector, req.data, headers,
#    1355                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# # Reverse row order

# %%
drinks.loc[::-1]
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 192     Zimbabwe             64               18              4
# 191       Zambia             32               19              4
# 190        Yemen              6                0              0
# 189      Vietnam            111                2              1
# 188    Venezuela            333              100              3
# ..           ...            ...              ...            ...
# 4         Angola            217               57             45
# 3        Andorra            245              138            312
# 2        Algeria             25                0             14
# 1        Albania             89              132             54
# 0    Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# ...

# %%
#now reset the index and declare last index as first index i.e. "O" (temporary)

drinks.loc[::-1].reset_index(drop=True).head()
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 0   Zimbabwe             64               18              4
# 1     Zambia             32               19              4
# 2      Yemen              6                0              0
# 3    Vietnam            111                2              1
# 4  Venezuela            333              100              3
#
#    total_litres_of_pure_alcohol      continent
# 0                           4.7         Africa
# 1                           2.5         Africa
# 2                           0.1           Asia
# 3                           2.0           Asia
# 4                           7.7  South America

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# # Reverse Column order

# %%
drinks.loc[:,::-1].head()
# Out:
#   continent  total_litres_of_pure_alcohol  wine_servings  spirit_servings  \
# 0      Asia                           0.0              0                0
# 1    Europe                           4.9             54              132
# 2    Africa                           0.7             14                0
# 3    Europe                          12.4            312              138
# 4    Africa                           5.9             45               57
#
#    beer_servings      country
# 0              0  Afghanistan
# 1             89      Albania
# 2             25      Algeria
# 3            245      Andorra
# 4            217       Angola

# %% [markdown]
# # Select columns by Data Type

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.select_dtypes(include="int64").head()
# Out:
#    beer_servings  spirit_servings  wine_servings
# 0              0                0              0
# 1             89              132             54
# 2             25                0             14
# 3            245              138            312
# 4            217               57             45

# %%
drinks.select_dtypes(include="object").head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
#also we can use exclude according to dtypes

drinks.select_dtypes(exclude="float64").head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings continent
# 0  Afghanistan              0                0              0      Asia
# 1      Albania             89              132             54    Europe
# 2      Algeria             25                0             14    Africa
# 3      Andorra            245              138            312    Europe
# 4       Angola            217               57             45    Africa

# %% [markdown]
# # Filter a dataframe by multiple categories

# %% [markdown]
# ### we can use Or (|) operator or "isin" method

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.genre=="Comedy")|(movies.genre=="Action")|(movies.star_rating>7.0)].head(n=15)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies[(movies.genre.isin(["Action","Adventure"]))].head()
# Out:
#     star_rating                                              title  \
# 3           9.0                                    The Dark Knight
# 7           8.9      The Lord of the Rings: The Return of the King
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
#
#    content_rating      genre  duration  \
# 3           PG-13     Action       152
# 7           PG-13  Adventure       201
# 10          PG-13  Adventure       178
# 11          PG-13     Action       148
# 12             PG     Action       124
#
#                                           actors_list
# 3   [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 7   [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10  [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 11  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# ...

# %%
movies[(movies.duration.isin([152,210,124,139,178,148,201]))].head(n=10)
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 148          8.2                                   The Elephant Man
# 150          8.2                                          Incendies
# 156          8.2                                             Casino
# 164          8.2                                      Into the Wild
#
#     content_rating      genre  duration  \
# 3            PG-13     Action       152
# 7            PG-13  Adventure       201
# 9                R      Drama       139
# 10           PG-13  Adventure       178
# ...

# %% [markdown]
# ## if we want alternative of this

# %%
movies[-(movies.duration.isin([152,210,124,139,178,148,201]))].head(n=10)
# Out:
#     star_rating                                  title content_rating  \
# 0           9.3               The Shawshank Redemption              R
# 1           9.2                          The Godfather              R
# 2           9.1                 The Godfather: Part II              R
# 4           8.9                           Pulp Fiction              R
# 5           8.9                           12 Angry Men      NOT RATED
# 6           8.9         The Good, the Bad and the Ugly      NOT RATED
# 8           8.9                       Schindler's List              R
# 13          8.8                           Forrest Gump          PG-13
# 14          8.8  The Lord of the Rings: The Two Towers          PG-13
# 15          8.7                           Interstellar          PG-13
#
#         genre  duration                                        actors_list
# 0       Crime       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
movies[-(movies.genre.isin(["Action","Adventure"]))].head()
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
# 4          8.9              Pulp Fiction              R  Crime       154
# 5          8.9              12 Angry Men      NOT RATED  Drama        96
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...

# %%
# for myself only


movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
movies[(movies.genre.isin(["Horror","Mystery"]))&(movies.duration>100)].sort_values(by="star_rating", ascending=False).head(30) #?
# Out:
#      star_rating                                              title  \
# 38           8.6                                        Rear Window
# 39           8.6                                             Psycho
# 46           8.5                                            Memento
# 57           8.5                                              Alien
# 62           8.5                                        The Shining
# 76           8.4                                            Vertigo
# 110          8.3                              2001: A Space Odyssey
# 149          8.2                                            Rebecca
# 161          8.2                                         Diabolique
# 186          8.2                                          The Thing
# 244          8.1                                     Shutter Island
# 249          8.1                                             Sleuth
# 264          8.1                                     Twelve Monkeys
# ...

# %% [markdown]
# # Handle Missing values

# %%
ufo.isna().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %%
ufo.isna().mean() #returns the percentage of null values
# Out:
# City               0.001371
# Colors Reported    0.842004
# Shape Reported     0.144948
# State              0.000000
# Time               0.000000
# dtype: float64

# %%
ufo.dropna(axis="columns").head(10) #drop the null values columns (temporary)
# Out:
#   State              Time
# 0    NY    6/1/1930 22:00
# 1    NJ   6/30/1930 20:00
# 2    CO   2/15/1931 14:00
# 3    KS    6/1/1931 13:00
# 4    NY   4/18/1933 19:00
# 5    ND   9/15/1934 15:30
# 6    CA    6/15/1935 0:00
# 7    MI    7/15/1936 0:00
# 8    AK  10/15/1936 17:00
# 9    OR    6/15/1937 0:00

# %%
ufo.dropna(thresh=len(ufo)*0.9,axis="columns").head() #drops the column which have 10% or more of null values
# Out:
#                    City State             Time
# 0                Ithaca    NY   6/1/1930 22:00
# 1           Willingboro    NJ  6/30/1930 20:00
# 2               Holyoke    CO  2/15/1931 14:00
# 3               Abilene    KS   6/1/1931 13:00
# 4  New York Worlds Fair    NY  4/18/1933 19:00

# %% [markdown]
# # Split a string into multiple columns

# %%
ufo.Time.str.split(" ",expand=True)
# Out:
#                 0      1
# 0        6/1/1930  22:00
# 1       6/30/1930  20:00
# 2       2/15/1931  14:00
# 3        6/1/1931  13:00
# 4       4/18/1933  19:00
# ...           ...    ...
# 18236  12/31/2000  23:00
# 18237  12/31/2000  23:00
# 18238  12/31/2000  23:45
# 18239  12/31/2000  23:45
# 18240  12/31/2000  23:59
#
# [18241 rows x 2 columns]

# %%
ufo[["date","time"]]=ufo.Time.str.split(" ",expand=True)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#         date   time
# 0   6/1/1930  22:00
# 1  6/30/1930  20:00
# 2  2/15/1931  14:00
# 3   6/1/1931  13:00
# 4  4/18/1933  19:00

# %%
ufo[ufo.City.isin(["Delhi","Faridabad"])]
# Out:
#         City Colors Reported Shape Reported State            Time      date  \
# 13443  Delhi          YELLOW        VARIOUS    CO  5/6/1999 20:00  5/6/1999
#
#         time
# 13443  20:00

# %% [markdown]
# # Expand a series of lists into a Dataframe

# %%
df=pd.DataFrame({"col_one":["a","b","c"],"col_two":[[10,40],[20,50],[30,60]]})
df
# Out:
#   col_one   col_two
# 0       a  [10, 40]
# 1       b  [20, 50]
# 2       c  [30, 60]

# %%
df_new= df.col_two.apply(pd.Series)
df_new
# Out:
#     0   1
# 0  10  40
# 1  20  50
# 2  30  60

# %%
pd.concat([df,df_new],axis="columns")
# Out:
#   col_one   col_two   0   1
# 0       a  [10, 40]  10  40
# 1       b  [20, 50]  20  50
# 2       c  [30, 60]  30  60

# %% [markdown]
# # Select a slice of rows and columns

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
titanic.describe().loc["min":"max"]
# Out:
#      PassengerId  Pclass    Age  SibSp  Parch      Fare
# min       892.00     1.0   0.17    0.0    0.0    0.0000
# 25%       996.25     1.0  21.00    0.0    0.0    7.8958
# 50%      1100.50     3.0  27.00    0.0    0.0   14.4542
# 75%      1204.75     3.0  39.00    1.0    0.0   31.5000
# max      1309.00     3.0  76.00    8.0    9.0  512.3292

# %%
titanic.describe().loc["min":"max","PassengerId":"SibSp"]
# Out:
#      PassengerId  Pclass    Age  SibSp
# min       892.00     1.0   0.17    0.0
# 25%       996.25     1.0  21.00    0.0
# 50%      1100.50     3.0  27.00    0.0
# 75%      1204.75     3.0  39.00    1.0
# max      1309.00     3.0  76.00    8.0

# %% [markdown]
# # convert continuos data into categorical data

# %%
titanic.Age.head(10)
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# 5    14.0
# 6    30.0
# 7    26.0
# 8    18.0
# 9    21.0
# Name: Age, dtype: float64

# %%
pd.cut(titanic.Age,bins=[0,18,25,99],labels=["child","Young Adult","Adult"]).head(10)
# Out:
# 0          Adult
# 1          Adult
# 2          Adult
# 3          Adult
# 4    Young Adult
# 5          child
# 6          Adult
# 7          Adult
# 8          child
# 9    Young Adult
# Name: Age, dtype: category
# Categories (3, object): ['child' < 'Young Adult' < 'Adult']

# %% [markdown]
# # Change display options

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# suppose I just want only 2 numbers after decimal in whole dataset

# %%
pd.set_option("display.float_format","{:.2f}".format)

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 0 34.50      0      0   330911  7.83   NaN        Q
# 1 47.00      1      0   363272  7.00   NaN        S
# 2 62.00      0      0   240276  9.69   NaN        Q
# 3 27.00      0      0   315154  8.66   NaN        S
# 4 22.00      1      1  3101298 12.29   NaN        S

# %%
# to reverse this back to original

# %%
pd.reset_option("display.float_format")

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # Style a Dataframe

# %%
stocks.head()
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT

# %%
format_dict={"Date":"{:%m%d%y}","Close":"${:.1f}"}

# %%
stocks.style.format(format_dict) #?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in _repr_html_(self)
#     203         Hooks into Jupyter notebook rich display system.
#     204         """
# --> 205         return self.render()
#     206
#     207     @doc(
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\style.py in render(self, **kwargs)
#     619         self._compute()
#     620         # TODO: namespace all the pandas keys
# --> 621         d = self._translate()
#     622         # filter out empty styles, every cell will have a class
# ...

# %% [markdown]
# # Profile a Dataframe

# %%
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-91-6a00893fb3e1> in <module>
# ----> 1 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %% [markdown]
# # check for equality

# %%
np.nan==np.nan
# Out:
# False

# %%
df=pd.DataFrame({"c":[1,2,3],"d":[1.0,2.0,3.0],"e":[1.0,2.0,3.0005]})
df
# Out:
#    c    d       e
# 0  1  1.0  1.0000
# 1  2  2.0  2.0000
# 2  3  3.0  3.0005

# %%
df.c.equals(df.d)
# Out:
# False

# %%
df.d.equals(df.e)
# Out:
# False

# %% [markdown]
# # Use numpy without importing numpy

# %%
np.random.seed(0)
pd.DataFrame(np.random.rand(2,3))
# Out:
#           0         1         2
# 0  0.548814  0.715189  0.602763
# 1  0.544883  0.423655  0.645894

# %%
pd.np.random.seed(0)
pd.DataFrame(pd.np.random.rand(2,3))   # pandas.np removed from pandas
# Out:
# <ipython-input-88-dfc247fef4e1>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.np.random.seed(0)
# <ipython-input-88-dfc247fef4e1>:2: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   pd.DataFrame(pd.np.random.rand(2,3))
#           0         1         2
# 0  0.548814  0.715189  0.602763
# 1  0.544883  0.423655  0.645894

# %%
df.loc[0,"e"]=pd.np.nan
# Out:
# <ipython-input-92-b4e4745ca24e>:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   df.loc[0,"e"]=pd.np.nan

# %%
df
# Out:
#    c    d       e
# 0  1  1.0     NaN
# 1  2  2.0  2.0000
# 2  3  3.0  3.0005

# %% [markdown]
# # Convert one set of Values to another

# %%
titanic.Sex.head()
# Out:
# 0      male
# 1    female
# 2      male
# 3      male
# 4    female
# Name: Sex, dtype: object

# %%
titanic["Sex_new"]=titanic.Sex.map({"male":1,"female":0})

# %%
titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Sex_new
# 0  34.5      0      0   330911   7.8292   NaN        Q        1
# 1  47.0      1      0   363272   7.0000   NaN        S        0
# 2  62.0      0      0   240276   9.6875   NaN        Q        1
# 3  27.0      0      0   315154   8.6625   NaN        S        1
# 4  22.0      1      1  3101298  12.2875   NaN        S        0

# %% [markdown]
# # Create a Datetime column from multiple columns

# %%
df=pd.DataFrame([[12,25,2022,"christmas"],[10,31,2022,"Halloween"]],columns=["month","day","year","holiday"])
df
# Out:
#    month  day  year    holiday
# 0     12   25  2022  christmas
# 1     10   31  2022  Halloween

# %%
df["Date"]= pd.to_datetime(df[["month","day","year"]]) 
df.dtypes
# Out:
# month               int64
# day                 int64
# year                int64
# holiday            object
# Date       datetime64[ns]
# dtype: object

# %%
df
# Out:
#    month  day  year    holiday       Date
# 0     12   25  2022  christmas 2022-12-25
# 1     10   31  2022  Halloween 2022-10-31

# %% [markdown]
# # Fill missing values using interpolation

# %%
df=pd.DataFrame({"d1":[1,2,3,np.nan,5,6],"d2":["a","b","c","d",np.nan,"f"]})
df
# Out:
#     d1   d2
# 0  1.0    a
# 1  2.0    b
# 2  3.0    c
# 3  NaN    d
# 4  5.0  NaN
# 5  6.0    f

# %%
df.interpolate() #works only on number dtypes , what about string dtypes columns
# Out:
#     d1   d2
# 0  1.0    a
# 1  2.0    b
# 2  3.0    c
# 3  4.0    d
# 4  5.0  NaN
# 5  6.0    f

# %%
stocks.head()
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT

# %% [markdown]
# ## Adding new row using ILoc

# %%
stocks.iloc[3]=["2020-2-22",12.33,1445466342,"CSCO"]

# %%
stocks
# Out:
#          Date   Close      Volume Symbol
# 0  2016-10-03   31.50    14070500   CSCO
# 1  2016-10-03  112.52    21701800   AAPL
# 2  2016-10-03   57.42    19189500   MSFT
# 3   2020-2-22   12.33  1445466342   CSCO
# 4  2016-10-04   57.24    20085900   MSFT
# 5  2016-10-04   31.35    18460400   CSCO
# 6  2016-10-05   57.64    16726400   MSFT
# 7  2016-10-05   31.59    11808600   CSCO
# 8  2016-10-05  113.05    21453100   AAPL
